# %% [markdown]
# <br>
#
# # <center> InstitutoTecnológico y de Estudios Superiores de Occidente </center>
# ## <center> Maestría Ciencia de Datos </center>
# ## <center> Investigación, Desarrollo e Innovación II </center>
# ## <center> Tarea 1: Método de Raphson para una variable  </center>
#
# <center> Estudiante: Daniel Nuño <br>
# Titular: Fernando Becerra <br>
# 10 Septiembre 2021 <br> </center>

# %% [markdown]
# <div style="page-break-after: always;"></div>
# <br>
# <br>
#
# Realice código en Python que, recibiendo una función f  dada, un valor inicial x0 y una exactitud (error) dado E , encuentre una aproximación de exactitud menor a E  para x cuando f(x)=0 usando el método de Newton-Raphson. Asegúrese que cuenta el número de iteraciones realizadas.
#
# Use su código para resolver los siguientes ejercicios (en todos los casos indique el(los) valor(es) inicial(es) que utilizó y el número de iteraciones que fueron necesarias para alcanzar la respuesta).
#
# Escriba sus respuestas con 10 cifras significativas.
#
# Aplique el método de Newton-Raphson para encontrar todas las soluciones exactas dentro de 10e−4.
#
# ### Funcón 1:
# $$ f(x) = x^3 - 2x^2 - 5 $$

# %%
import sympy as sp

x = sp.symbols('x')
sp.init_printing(use_unicode=True)
f = x**3 - 2*x**2 - 5
f_derivada = f.diff(x,1)
x0 = 5
exactitud = 10e-4
iteraciones = 0
list_resultados = [x0]
error = 1
sp.plotting.plot(f,  xlim=(-5, 5), ylim=(-10,10))
# Out:
# <bound method Printable.__str__ of x**3 - 2*x**2 - 5>

# %% [markdown]
# Observamos que tiene una raíz entre 0 y 2.5. Comenzamos X0 en 3.

# %%
while error >= exactitud:
    iteraciones += 1
    y = f.evalf(subs={x: x0})
    y_derivada = f_derivada.evalf(subs={x: x0})
    x1 = sp.N(x0 - y/y_derivada, 10)
    list_resultados.append(x1)
    error = abs(x1 - x0)
    x0 = x1

print('El número de iteraciones fue: ' + str(iteraciones))
print('Usando x inicial: ' + str(list_resultados[0]))
print('La raíz es cercana a: ' + str(list_resultados[-1]))
# Out:
# El número de iteraciones fue: 6
# Usando x inicial: 5
# La raíz es cercana a: 2.690647448

# %% [markdown]
# ### Funcón 2:
# $$ f(x) = x - cos(x) $$

# %%
x = sp.symbols('x')
f = x - sp.cos(x)
f_derivada = f.diff(x,1)
exactitud = 10e-4
iteraciones = 0
error = 1
sp.plotting.plot(f,  xlim=(-10, 10), ylim=(-10,10))
f
# Out:
# x - cos(x)

# %% [markdown]
# Observamos que tiene una raíz entre 0 y 2. Comenzamos X0 en 1.

# %%
x0 = 1
list_resultados = [x0]

while error >= exactitud:
    iteraciones += 1
    y = f.evalf(subs={x: x0})
    y_derivada = f_derivada.evalf(subs={x: x0})
    x1 = sp.N(x0 - y/y_derivada, 10)
    list_resultados.append(x1)
    error = abs(x1 - x0)
    x0 = x1

print('El número de iteraciones fue: ' + str(iteraciones))
print('Usando x inicial: ' + str(list_resultados[0]))
print('La raíz es cercana a: ' + str(list_resultados[-1]))
# Out:
# El número de iteraciones fue: 3
# Usando x inicial: 1
# La raíz es cercana a: 0.7390851334

# %% [markdown]
# ### Funcón 3:
# $$ f(x) = x - 0.8 - 0.2sp.sin(x) $$

# %%
x = sp.symbols('x')
f = x - 0.8 - 0.2*sp.sin(x)
f_derivada = f.diff(x,1)
exactitud = 10e-4
iteraciones = 0
error = 1
sp.plotting.plot(f,  xlim=(-10, 10), ylim=(-10,10))
f
# Out:
# x - 0.2⋅sin(x) - 0.8

# %% [markdown]
# Observamos que tiene una raíz entre 0 y 2. Comenzamos X0 en 1.

# %%
x0 = 1
list_resultados = [x0]

while error >= exactitud:
    iteraciones += 1
    y = f.evalf(subs={x: x0})
    y_derivada = f_derivada.evalf(subs={x: x0})
    x1 = sp.N(x0 - y/y_derivada, 10)
    list_resultados.append(x1)
    error = abs(x1 - x0)
    x0 = x1

print('El número de iteraciones fue: ' + str(iteraciones))
print('Usando x inicial: ' + str(list_resultados[0]))
print('La raíz es cercana a: ' + str(list_resultados[-1]))
# Out:
# El número de iteraciones fue: 2
# Usando x inicial: 1
# La raíz es cercana a: 0.9643338890

# %% [markdown]
# ### Funcón 4:
# $$ f(x) = ln(x-1) + cos(x-1) $$

# %%
x = sp.symbols('x')
f = sp.log(x-1) + sp.cos(x-1)
f_derivada = f.diff(x,1)
exactitud = 10e-4
iteraciones = 0
error = 1
sp.plotting.plot(f,  xlim=(-10, 10), ylim=(-10,10))
f
# Out:
# log(x - 1) + cos(x - 1)

# %% [markdown]
# Observamos que tiene una raíz entre 0 y 2. Comenzamos X0 en 1.3.

# %%
x0 = 1.3
list_resultados = [x0]

while error >= exactitud:
    iteraciones += 1
    y = f.evalf(subs={x: x0})
    y_derivada = f_derivada.evalf(subs={x: x0})
    x1 = sp.N(x0 - y/y_derivada, 10)
    list_resultados.append(x1)
    error = abs(x1 - x0)
    x0 = x1

print('El número de iteraciones fue: ' + str(iteraciones))
print('Usando x inicial: ' + str(list_resultados[0]))
print('La raíz es cercana a: ' + str(list_resultados[-1]))
# Out:
# El número de iteraciones fue: 3
# Usando x inicial: 1.3
# La raíz es cercana a: 1.397748164

# %% [markdown]
# ### Funcón 5: $$ f(x) = e^x - 3x^2 $$

# %%
x = sp.symbols('x')
f = sp.exp(x) - 3*x**2
f_derivada = f.diff(x,1)
exactitud = 10e-4
iteraciones = 0
error = 1
sp.plotting.plot(f,  xlim=(-10, 10), ylim=(-10,10))
f
# Out:
#      2    x
# - 3⋅x  + ℯ

# %% [markdown]
# Observamos que tiene una raíz 3 raices entre -1 y 5. Comenzamos X0 en 0 para buscar la primer raíz.

# %%
x0 = 0
list_resultados = [x0]

while error >= exactitud:
    iteraciones += 1
    y = f.evalf(subs={x: x0})
    y_derivada = f_derivada.evalf(subs={x: x0})
    x1 = sp.N(x0 - y/y_derivada, 10)
    list_resultados.append(x1)
    error = abs(x1 - x0)
    x0 = x1

print('El número de iteraciones fue: ' + str(iteraciones))
print('Usando x inicial: ' + str(list_resultados[0]))
print('La raíz es cercana a: ' + str(list_resultados[-1]))
# Out:
# El número de iteraciones fue: 5
# Usando x inicial: 0
# La raíz es cercana a: -0.4589622742

# %% [markdown]
# Ahora buscamos la segunda raíz y comenzamos X0 en 1.5.

# %%
x0 = 1.5
list_resultados = [x0]

while error >= exactitud:
    iteraciones += 1
    y = f.evalf(subs={x: x0})
    y_derivada = f_derivada.evalf(subs={x: x0})
    x1 = sp.N(x0 - y/y_derivada, 10)
    list_resultados.append(x1)
    error = abs(x1 - x0)
    x0 = x1

print('El número de iteraciones fue: ' + str(iteraciones))
print('Usando x inicial: ' + str(list_resultados[0]))
print('La raíz es cercana a: ' + str(list_resultados[-1]))
# Out:
# El número de iteraciones fue: 5
# Usando x inicial: 1.5
# La raíz es cercana a: 1.5

# %% [markdown]
# Ahora buscamos la tercera raíz y comenzamos X0 en 4.

# %%
x0 = 4
list_resultados = [x0]

while error >= exactitud:
    iteraciones += 1
    y = f.evalf(subs={x: x0})
    y_derivada = f_derivada.evalf(subs={x: x0})
    x1 = sp.N(x0 - y/y_derivada, 10)
    list_resultados.append(x1)
    error = abs(x1 - x0)
    x0 = x1

print('El número de iteraciones fue: ' + str(iteraciones))
print('Usando x inicial: ' + str(list_resultados[0]))
print('La raíz es cercana a: ' + str(list_resultados[-1]))
# Out:
# El número de iteraciones fue: 5
# Usando x inicial: 4
# La raíz es cercana a: 4

# %% [markdown]
# ### Encontrar la raiz de: $$ \sqrt(5) $$

# %%
x = sp.symbols('x')
f = sp.sqrt(5)
exactitud = 10e-4
iteraciones = 0
error = 1

# %%
number = 5 
x0 = number
list_resultados = [sp.N(0.5 * (x0 + number/x0), 10)]

while error >= exactitud:
    iteraciones += 1
    x1 = sp.N(0.5 * (x0 + number/x0), 10)
    list_resultados.append(x1)
    error = abs(x1 - x0)
    x0 = x1

print('El número de iteraciones fue: ' + str(iteraciones))
print('Usando x inicial: ' + str(list_resultados[0]))
print('La raíz es cercana a: ' + str(list_resultados[-1]))
# Out:
# El número de iteraciones fue: 5
# Usando x inicial: 3.000000000
# La raíz es cercana a: 2.236067978

# %% [markdown]
# Encuentre el único cero negativo de $$ f(x)=ln(x^2+1)−e^(0.4x)cos(πx) $$ con exactitud de 10e−6  usando Newton-Raphson

# %%
x = sp.symbols('x')
f = sp.log(x**2+1) - sp.exp(0.4*x) * sp.cos(sp.pi*x)
f_derivada = f.diff(x,1)
exactitud = 10e-6
iteraciones = 0
error = 1
sp.plotting.plot(f,  xlim=(-10, 10), ylim=(-10,10))
f
# Out:
#    0.4⋅x               ⎛ 2    ⎞
# - ℯ     ⋅cos(π⋅x) + log⎝x  + 1⎠

# %%
x0 = -2
list_resultados = [x0]

while error >= exactitud:
    iteraciones += 1
    y = f.evalf(subs={x: x0})
    y_derivada = f_derivada.evalf(subs={x: x0})
    x1 = sp.N(x0 - y/y_derivada, 10)
    list_resultados.append(x1)
    error = abs(x1 - x0)
    x0 = x1

print('El número de iteraciones fue: ' + str(iteraciones))
print('Usando x inicial: ' + str(list_resultados[0]))
print('La raíz es cercana a: ' + str(list_resultados[-1]))
# Out:
# El número de iteraciones fue: 6
# Usando x inicial: -2
# La raíz es cercana a: -0.4341430473

# %% [markdown]
# ### código usado:

# %%
# %%script echo skipping
#
# x = sp.symbols('x')
# f = sp.log(x**2+1) - sp.exp(0.4*x) * sp.cos(sp.pi*x)
# f_derivada = f.diff(x,1)
# exactitud = 10e-6
# iteraciones = 0
# error = 1
#
# x0 = -2
# list_resultados = [x0]
#
# while error >= exactitud:
#     iteraciones += 1
#     y = f.evalf(subs={x: x0})
#     y_derivada = f_derivada.evalf(subs={x: x0})
#     x1 = sp.N(x0 - y/y_derivada, 10)
#     list_resultados.append(x1)
#     error = abs(x1 - x0)
#     x0 = x1
#
# print('El número de iteraciones fue: ' + str(iteraciones))
# print('Usando x inicial: ' + str(list_resultados[0]))
# print('La raíz es cercana a: ' + str(list_resultados[-1]))
# Out:
# Couldn't find program: 'echo'
